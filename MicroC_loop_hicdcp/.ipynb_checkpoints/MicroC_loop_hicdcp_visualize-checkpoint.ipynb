# %% [markdown]
# ## Setting

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter("ignore", category=FutureWarning)

# %%
# Import standard python libraries
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 300
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os, subprocess

# %%
from coolpuppy import coolpup
from coolpuppy.lib import numutils
from coolpuppy.lib.puputils import divide_pups
from coolpuppy import plotpup
import cooler
import bioframe
import cooltools
from cooltools import expected_cis, expected_trans
from cooltools.lib import plotting

# %% [markdown]
# # Functions for generalization

# %%
import copy

def callAPAoverLoop(coolFileDir, coolFileName, loopFileDir, loopFileName, minDiag, byDistance, balance, ooe):
    # minDist = minimun distance in kb to plot in APA
    # Load cool file
    cool_file = coolFileDir + '/' + coolFileName + '_KR.cool'
    clr = cooler.Cooler(f'{cool_file}')
    # Load loop file
    loop_file = loopFileDir + '/' + loopFileName + '.bedpe'
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
    # Load expected table
    exp_file = coolFileDir + '/' + coolFileName + '_KR_exp.tsv'
    exp_df = pd.read_csv(exp_file, delimiter='\t')

    # keep loop count
    nloops = len(loop)
    
    # Pileup
    if ooe:
        pup = coolpup.pileup(clr, loop, features_format = 'bedpe',
                             min_diag = minDiag, by_distance = byDistance,
                             nproc = 12, 
                             clr_weight_name = balance,
                             ooe = True, expected_df = exp_df)
    else:
         pup = coolpup.pileup(clr, loop, features_format = 'bedpe',
                             min_diag = minDiag, by_distance = byDistance,
                             nproc = 12, 
                             clr_weight_name = balance,
                             ooe = False)       
    return pup, nloops

def get_corner_score(pup, flank = 1):
    amap = pup["data"][0]
    c = amap.shape[0] / (flank*2 + 1)
    c = int(c)
    central = np.nanmean(amap[flank*c:-flank:c, flank*c:-flank*c])
    topRight = np.nanmean(amap[:c, -c:])
    cornerScore = central/topRight
    return cornerScore, central, topRight


def drawAPA(pup, nloops, scale, colormap, vmax, vmin, fileDir, fileName):
    puptemp = copy.deepcopy(pup)
    if scale == 'log10':
        puptemp.data[0] = np.log10(puptemp.data[0])
    # Make figure
    # Enrichment score is calculated by ratio of C(obs/exp) to R (obs/exp) before doing any form of log transform
    corner = str(round(get_corner_score(pup, flank = 2)[0], 2))
    
    if vmax == False:
        fg1 = plotpup.plot(puptemp,
                           cmap = colormap,
                           score = False, 
                           scale = 'linear', height = 1, plot_ticks = True, font_scale = 0.8)
        ax = fg1.ax
        ax.text(
            0.95, 0.95,                   # 95% from left, 95% from bottom
            f"corner score: {corner}",
            va="top", ha="right",
            transform=ax.transAxes,       # ← important!
            size=4
        )
        ax.text(
            0.95, 0.85,
            f"n loops: {nloops}",
            va="top", ha="right",
            transform=ax.transAxes,
            size=4
        )
    else:
        fg1 = plotpup.plot(puptemp,
                   cmap = colormap,
                   score = False, vmax = vmax, vmin = vmin,
                   scale = 'linear', height = 1, plot_ticks = True, font_scale = 0.8)
        ax = fg1.ax
        ax.text(
            0.95, 0.95,                   # 95% from left, 95% from bottom
            f"corner score: {corner}",
            va="top", ha="right",
            transform=ax.transAxes,       # ← important!
            size=4
        )
        ax.text(
            0.95, 0.85,
            f"n loops: {nloops}",
            va="top", ha="right",
            transform=ax.transAxes,
            size=4
        )
    file = fileDir + '/' + fileName + '.svg'
    fg1.savefig(file, format = 'svg')
    return True

# %% [markdown]
# # APA plot

# %%
# LOADING COOL FILE
coolDir = '/Volumes/UKJIN_SSD/data/cool_norm_pooled'
figDir = '/Volumes/UKJIN_SSD/figure/loop_hicdcp'
loopDir = '/Volumes/UKJIN_SSD/data/loop_hicdcp'

os.makedirs(figDir, exist_ok=True)

# %%
cutoffs = [0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0]

for res in ['10000']:
    for sample in ['G1dTAG_pooled', 'G1A485_pooled']:
        for i in range(len(cutoffs) - 1):
            upper = cutoffs[i]
            lower = cutoffs[i + 1]
            tag   = f"{upper}_{lower}"
            bedpe = f"testing_{sample}_10kb_hicdcplus_qval{tag}"
            try:
                pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'bp',
                        loopDir, bedpe,
                        minDiag = 2, byDistance = False,
                        balance = 'weight', ooe = True)
                fileName = 'APA_' + sample + '_hicdcp_10kb_qval' + tag
                drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                        fileDir = figDir, fileName = fileName)
                # drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = 1, vmin = 0,
                #           fileDir = figDir, fileName = fileName + '_minmax')
            except:
                print(f"Failed to process {sample} at resolution {res} with cutoff {tag}")
                continue
# Out:
# python(16041) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16042) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16043) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16045) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16047) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16048) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16049) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 140
# INFO:coolpuppy:('chr9', 'chr9'): 240
# INFO:coolpuppy:('chr4', 'chr4'): 174
# INFO:coolpuppy:('chr8', 'chr8'): 218
# INFO:coolpuppy:('chr5', 'chr5'): 191
# INFO:coolpuppy:('chr6', 'chr6'): 272
# INFO:coolpuppy:('chr3', 'chr3'): 450
# INFO:coolpuppy:('chr7', 'chr7'): 177
# INFO:coolpuppy:('chr10', 'chr10'): 227
# INFO:coolpuppy:('chr13', 'chr13'): 232
# INFO:coolpuppy:('chr2', 'chr2'): 303
# INFO:coolpuppy:('chr19', 'chr19'): 78
# INFO:coolpuppy:('chrX', 'chrX'): 183
# INFO:coolpuppy:('chr11', 'chr11'): 262
# INFO:coolpuppy:('chr15', 'chr15'): 127
# INFO:coolpuppy:('chr17', 'chr17'): 82
# INFO:coolpuppy:('chr16', 'chr16'): 153
# INFO:coolpuppy:('chr18', 'chr18'): 119
# INFO:coolpuppy:('chr1', 'chr1'): 346
# INFO:coolpuppy:('chr14', 'chr14'): 79
# INFO:coolpuppy:Total number of piled up windows: 4053
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16087) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16088) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16089) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16090) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16091) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16092) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16093) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16094) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16095) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16096) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16097) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16098) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 124
# INFO:coolpuppy:('chr8', 'chr8'): 156
# INFO:coolpuppy:('chr9', 'chr9'): 194
# INFO:coolpuppy:('chr10', 'chr10'): 198
# INFO:coolpuppy:('chr7', 'chr7'): 151
# INFO:coolpuppy:('chr6', 'chr6'): 194
# INFO:coolpuppy:('chr4', 'chr4'): 130
# INFO:coolpuppy:('chr3', 'chr3'): 316
# INFO:coolpuppy:('chr5', 'chr5'): 126
# INFO:coolpuppy:('chr11', 'chr11'): 173
# INFO:coolpuppy:('chr17', 'chr17'): 56
# INFO:coolpuppy:('chr1', 'chr1'): 281
# INFO:coolpuppy:('chr2', 'chr2'): 225
# INFO:coolpuppy:('chr15', 'chr15'): 104
# INFO:coolpuppy:('chr16', 'chr16'): 114
# INFO:coolpuppy:('chr19', 'chr19'): 44
# INFO:coolpuppy:('chr13', 'chr13'): 209
# INFO:coolpuppy:('chr14', 'chr14'): 46
# INFO:coolpuppy:('chrX', 'chrX'): 181
# INFO:coolpuppy:('chr18', 'chr18'): 105
# INFO:coolpuppy:Total number of piled up windows: 3127
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16126) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16127) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16128) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16129) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16130) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16131) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16132) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16133) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16134) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16135) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16136) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16137) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 10
# INFO:coolpuppy:('chr4', 'chr4'): 19
# INFO:coolpuppy:('chr9', 'chr9'): 20
# INFO:coolpuppy:('chr6', 'chr6'): 14
# INFO:coolpuppy:('chr2', 'chr2'): 24
# INFO:coolpuppy:('chr10', 'chr10'): 26
# INFO:coolpuppy:('chr7', 'chr7'): 40
# INFO:coolpuppy:('chr8', 'chr8'): 14
# INFO:coolpuppy:('chr5', 'chr5'): 12
# INFO:coolpuppy:('chr13', 'chr13'): 46
# INFO:coolpuppy:('chr3', 'chr3'): 20
# INFO:coolpuppy:('chr11', 'chr11'): 20
# INFO:coolpuppy:('chr1', 'chr1'): 22
# INFO:coolpuppy:('chr14', 'chr14'): 5
# INFO:coolpuppy:('chr19', 'chr19'): 4
# INFO:coolpuppy:('chr17', 'chr17'): 5
# INFO:coolpuppy:('chrX', 'chrX'): 38
# INFO:coolpuppy:('chr18', 'chr18'): 9
# INFO:coolpuppy:('chr15', 'chr15'): 9
# INFO:coolpuppy:('chr16', 'chr16'): 8
# INFO:coolpuppy:Total number of piled up windows: 365
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16190) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16191) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16192) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16193) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16194) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16195) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16196) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16197) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16200) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 17
# INFO:coolpuppy:('chr9', 'chr9'): 19
# INFO:coolpuppy:('chr8', 'chr8'): 17
# INFO:coolpuppy:('chr7', 'chr7'): 41
# INFO:coolpuppy:('chr3', 'chr3'): 49
# INFO:coolpuppy:('chr6', 'chr6'): 28
# INFO:coolpuppy:('chr5', 'chr5'): 17
# INFO:coolpuppy:('chr4', 'chr4'): 25
# INFO:coolpuppy:('chr2', 'chr2'): 21
# INFO:coolpuppy:('chr10', 'chr10'): 19
# INFO:coolpuppy:('chr16', 'chr16'): 10
# INFO:coolpuppy:('chr11', 'chr11'): 18
# INFO:coolpuppy:('chr19', 'chr19'): 6
# INFO:coolpuppy:('chrX', 'chrX'): 47
# INFO:coolpuppy:('chr17', 'chr17'): 2
# INFO:coolpuppy:('chr15', 'chr15'): 7
# INFO:coolpuppy:('chr13', 'chr13'): 83
# INFO:coolpuppy:('chr14', 'chr14'): 5
# INFO:coolpuppy:('chr18', 'chr18'): 9
# INFO:coolpuppy:('chr1', 'chr1'): 32
# INFO:coolpuppy:Total number of piled up windows: 472
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16269) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16270) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16271) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16272) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16273) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16274) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16275) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16276) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16277) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16278) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16279) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16280) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 2
# INFO:coolpuppy:('chr8', 'chr8'): 2
# INFO:coolpuppy:('chr10', 'chr10'): 4
# INFO:coolpuppy:('chr9', 'chr9'): 1
# INFO:coolpuppy:('chr13', 'chr13'): 20
# INFO:coolpuppy:('chr4', 'chr4'): 7
# INFO:coolpuppy:('chr5', 'chr5'): 1
# INFO:coolpuppy:('chr7', 'chr7'): 11
# INFO:coolpuppy:('chr6', 'chr6'): 2
# INFO:coolpuppy:('chr11', 'chr11'): 3
# INFO:coolpuppy:('chr19', 'chr19'): 2
# INFO:coolpuppy:('chr3', 'chr3'): 5
# INFO:coolpuppy:('chr17', 'chr17'): 1
# INFO:coolpuppy:('chr2', 'chr2'): 4
# INFO:coolpuppy:('chrX', 'chrX'): 6
# INFO:coolpuppy:('chr18', 'chr18'): 1
# INFO:coolpuppy:('chr1', 'chr1'): 4
# INFO:coolpuppy:('chr15', 'chr15'): 1
# INFO:coolpuppy:Total number of piled up windows: 77
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16385) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16386) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16387) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16388) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16389) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16390) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16391) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16392) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16393) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16394) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16395) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16396) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 1
# INFO:coolpuppy:('chr5', 'chr5'): 1
# INFO:coolpuppy:('chr9', 'chr9'): 3
# INFO:coolpuppy:('chr3', 'chr3'): 12
# INFO:coolpuppy:('chr10', 'chr10'): 16
# INFO:coolpuppy:('chr8', 'chr8'): 4
# INFO:coolpuppy:('chr7', 'chr7'): 42
# INFO:coolpuppy:('chr6', 'chr6'): 5
# INFO:coolpuppy:('chr13', 'chr13'): 426
# INFO:coolpuppy:('chr4', 'chr4'): 58
# INFO:coolpuppy:('chr2', 'chr2'): 4
# INFO:coolpuppy:('chr11', 'chr11'): 4
# INFO:coolpuppy:('chr1', 'chr1'): 7
# INFO:coolpuppy:('chr19', 'chr19'): 1
# INFO:coolpuppy:('chrX', 'chrX'): 30
# INFO:coolpuppy:('chr18', 'chr18'): 1
# INFO:coolpuppy:('chr14', 'chr14'): 12
# INFO:coolpuppy:('chr15', 'chr15'): 4
# INFO:coolpuppy:('chr17', 'chr17'): 5
# INFO:coolpuppy:Total number of piled up windows: 636
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16470) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16471) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16472) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16473) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16474) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16475) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16476) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16477) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16478) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16479) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16480) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16481) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 891
# INFO:coolpuppy:('chr8', 'chr8'): 740
# INFO:coolpuppy:('chr13', 'chr13'): 1018
# INFO:coolpuppy:('chr9', 'chr9'): 1431
# INFO:coolpuppy:('chr7', 'chr7'): 469
# INFO:coolpuppy:('chr1', 'chr1'): 2271
# INFO:coolpuppy:('chr4', 'chr4'): 661
# INFO:coolpuppy:('chr5', 'chr5'): 991
# INFO:coolpuppy:('chr14', 'chr14'): 441
# INFO:coolpuppy:('chr6', 'chr6'): 1219
# INFO:coolpuppy:('chr10', 'chr10'): 1166
# INFO:coolpuppy:('chr3', 'chr3'): 1595
# INFO:coolpuppy:('chr15', 'chr15'): 841
# INFO:coolpuppy:('chr17', 'chr17'): 355
# INFO:coolpuppy:('chr16', 'chr16'): 1060
# INFO:coolpuppy:('chr18', 'chr18'): 927
# INFO:coolpuppy:('chr11', 'chr11'): 1556
# INFO:coolpuppy:('chrX', 'chrX'): 430
# INFO:coolpuppy:('chr19', 'chr19'): 421
# INFO:coolpuppy:('chr2', 'chr2'): 1788
# INFO:coolpuppy:Total number of piled up windows: 20271
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16627) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16628) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16629) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16630) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16631) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16632) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16634) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16635) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16636) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16637) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16638) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16639) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 993
# INFO:coolpuppy:('chr9', 'chr9'): 1517
# INFO:coolpuppy:('chr8', 'chr8'): 743
# INFO:coolpuppy:('chr6', 'chr6'): 1236
# INFO:coolpuppy:('chr4', 'chr4'): 645
# INFO:coolpuppy:('chr10', 'chr10'): 1180
# INFO:coolpuppy:('chr3', 'chr3'): 1636
# INFO:coolpuppy:('chr5', 'chr5'): 999
# INFO:coolpuppy:('chr11', 'chr11'): 1628
# INFO:coolpuppy:('chr7', 'chr7'): 431
# INFO:coolpuppy:('chr19', 'chr19'): 465
# INFO:coolpuppy:('chrX', 'chrX'): 452
# INFO:coolpuppy:('chr17', 'chr17'): 349
# INFO:coolpuppy:('chr18', 'chr18'): 873
# INFO:coolpuppy:('chr13', 'chr13'): 1030
# INFO:coolpuppy:('chr16', 'chr16'): 1058
# INFO:coolpuppy:('chr15', 'chr15'): 953
# INFO:coolpuppy:('chr14', 'chr14'): 466
# INFO:coolpuppy:('chr2', 'chr2'): 1868
# INFO:coolpuppy:('chr1', 'chr1'): 2211
# INFO:coolpuppy:Total number of piled up windows: 20733
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16731) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16732) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16733) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16734) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16735) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16736) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16737) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16738) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16739) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16740) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16741) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16742) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 179
# INFO:coolpuppy:('chr9', 'chr9'): 304
# INFO:coolpuppy:('chr3', 'chr3'): 363
# INFO:coolpuppy:('chr6', 'chr6'): 215
# INFO:coolpuppy:('chr7', 'chr7'): 92
# INFO:coolpuppy:('chr5', 'chr5'): 152
# INFO:coolpuppy:('chr10', 'chr10'): 232
# INFO:coolpuppy:('chr8', 'chr8'): 144
# INFO:coolpuppy:('chr4', 'chr4'): 134
# INFO:coolpuppy:('chr17', 'chr17'): 95
# INFO:coolpuppy:('chr11', 'chr11'): 352
# INFO:coolpuppy:('chr16', 'chr16'): 226
# INFO:coolpuppy:('chr15', 'chr15'): 216
# INFO:coolpuppy:('chr13', 'chr13'): 244
# INFO:coolpuppy:('chr19', 'chr19'): 91
# INFO:coolpuppy:('chrX', 'chrX'): 90
# INFO:coolpuppy:('chr14', 'chr14'): 86
# INFO:coolpuppy:('chr18', 'chr18'): 165
# INFO:coolpuppy:('chr1', 'chr1'): 418
# INFO:coolpuppy:('chr2', 'chr2'): 371
# INFO:coolpuppy:Total number of piled up windows: 4169
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(16913) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16914) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16917) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16918) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16919) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16920) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16921) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16923) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16924) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(16925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 203
# INFO:coolpuppy:('chr13', 'chr13'): 315
# INFO:coolpuppy:('chr14', 'chr14'): 88
# INFO:coolpuppy:('chr7', 'chr7'): 87
# INFO:coolpuppy:('chr4', 'chr4'): 188
# INFO:coolpuppy:('chr5', 'chr5'): 237
# INFO:coolpuppy:('chr8', 'chr8'): 158
# INFO:coolpuppy:('chr6', 'chr6'): 297
# INFO:coolpuppy:('chr10', 'chr10'): 276
# INFO:coolpuppy:('chr9', 'chr9'): 394
# INFO:coolpuppy:('chr3', 'chr3'): 433
# INFO:coolpuppy:('chr15', 'chr15'): 262
# INFO:coolpuppy:('chr11', 'chr11'): 476
# INFO:coolpuppy:('chr19', 'chr19'): 125
# INFO:coolpuppy:('chrX', 'chrX'): 132
# INFO:coolpuppy:('chr1', 'chr1'): 613
# INFO:coolpuppy:('chr2', 'chr2'): 400
# INFO:coolpuppy:('chr17', 'chr17'): 82
# INFO:coolpuppy:('chr18', 'chr18'): 190
# INFO:coolpuppy:('chr16', 'chr16'): 262
# INFO:coolpuppy:Total number of piled up windows: 5218
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(17028) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17029) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17030) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17031) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17032) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17033) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17034) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17035) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17036) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17037) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17038) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17039) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 54
# INFO:coolpuppy:('chr10', 'chr10'): 71
# INFO:coolpuppy:('chr4', 'chr4'): 52
# INFO:coolpuppy:('chr9', 'chr9'): 117
# INFO:coolpuppy:('chr8', 'chr8'): 50
# INFO:coolpuppy:('chr5', 'chr5'): 45
# INFO:coolpuppy:('chr3', 'chr3'): 104
# INFO:coolpuppy:('chr16', 'chr16'): 62
# INFO:coolpuppy:('chr13', 'chr13'): 104
# INFO:coolpuppy:('chr15', 'chr15'): 63
# INFO:coolpuppy:('chr14', 'chr14'): 25
# INFO:coolpuppy:('chr7', 'chr7'): 21
# INFO:coolpuppy:('chr19', 'chr19'): 23
# INFO:coolpuppy:('chr2', 'chr2'): 100
# INFO:coolpuppy:('chrX', 'chrX'): 32
# INFO:coolpuppy:('chr17', 'chr17'): 25
# INFO:coolpuppy:('chr1', 'chr1'): 147
# INFO:coolpuppy:('chr18', 'chr18'): 45
# INFO:coolpuppy:('chr6', 'chr6'): 84
# INFO:coolpuppy:('chr11', 'chr11'): 110
# INFO:coolpuppy:Total number of piled up windows: 1334
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# python(17103) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17105) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17107) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17108) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17109) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17110) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17111) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17112) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17113) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17115) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17116) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(17117) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# INFO:coolpuppy:('chr12', 'chr12'): 121
# INFO:coolpuppy:('chr8', 'chr8'): 150
# INFO:coolpuppy:('chr9', 'chr9'): 470
# INFO:coolpuppy:('chr6', 'chr6'): 245
# INFO:coolpuppy:('chr4', 'chr4'): 178
# INFO:coolpuppy:('chr10', 'chr10'): 279
# INFO:coolpuppy:('chr7', 'chr7'): 52
# INFO:coolpuppy:('chr3', 'chr3'): 379
# INFO:coolpuppy:('chr19', 'chr19'): 91
# INFO:coolpuppy:('chr5', 'chr5'): 158
# INFO:coolpuppy:('chrX', 'chrX'): 95
# INFO:coolpuppy:('chr18', 'chr18'): 159
# INFO:coolpuppy:('chr17', 'chr17'): 65
# INFO:coolpuppy:('chr16', 'chr16'): 276
# INFO:coolpuppy:('chr14', 'chr14'): 75
# INFO:coolpuppy:('chr13', 'chr13'): 551
# INFO:coolpuppy:('chr15', 'chr15'): 221
# INFO:coolpuppy:('chr11', 'chr11'): 335
# INFO:coolpuppy:('chr2', 'chr2'): 345
# INFO:coolpuppy:('chr1', 'chr1'): 552
# INFO:coolpuppy:Total number of piled up windows: 4797
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical

# %%
res = '5'
maxV = 0.6
for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_DMSO_specific',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_DMSOspecific_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = maxV, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')

for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_dTAG_specific',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_dTAGspecific_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = maxV, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')

for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_common',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_common_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = maxV, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')

# %%
res = '5'
maxV = 0.6
for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_NCAPH2_TT',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_NCAPH2_TT_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = 0.35, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')

for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_NCAPH2_TFFT_TForder',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_NCAPH2_TF_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')

for sample in ['D3-DMSO_pooled', 'D3-dTAG_pooled']:
    pup, nloops = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
              loopDir, 'chromo_cons_allRes_postprocessed_NCAPH2_FF',
              minDiag = 2, byDistance = False,
              balance = 'weight', ooe = True)
    fileName = 'APA_NCAPH2_FF_' + sample
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
            fileDir = figDir, fileName = fileName)
    drawAPA(pup, nloops, scale = 'log10', colormap = 'coolwarm', vmax = 0.5, vmin = 0,
            fileDir = figDir, fileName = fileName + '_minmax')
# Out:
# INFO:coolpuppy:('chr12', 'chr12'): 5
# INFO:coolpuppy:('chr11', 'chr11'): 17
# INFO:coolpuppy:('chr9', 'chr9'): 13
# INFO:coolpuppy:('chr8', 'chr8'): 23
# INFO:coolpuppy:('chr10', 'chr10'): 11
# INFO:coolpuppy:('chr7', 'chr7'): 9
# INFO:coolpuppy:('chr13', 'chr13'): 4
# INFO:coolpuppy:('chr4', 'chr4'): 9
# INFO:coolpuppy:('chr5', 'chr5'): 14
# INFO:coolpuppy:('chr6', 'chr6'): 8
# INFO:coolpuppy:('chr14', 'chr14'): 3
# INFO:coolpuppy:('chr15', 'chr15'): 13
# INFO:coolpuppy:('chr16', 'chr16'): 12
# INFO:coolpuppy:('chr17', 'chr17'): 8
# INFO:coolpuppy:('chr19', 'chr19'): 6
# INFO:coolpuppy:('chr1', 'chr1'): 18
# INFO:coolpuppy:('chr18', 'chr18'): 5
# INFO:coolpuppy:('chr2', 'chr2'): 22
# INFO:coolpuppy:('chr3', 'chr3'): 7
# INFO:coolpuppy:('chrX', 'chrX'): 4
# INFO:coolpuppy:Total number of piled up windows: 211
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
# INFO:coolpuppy:('chr12', 'chr12'): 5
# INFO:coolpuppy:('chr11', 'chr11'): 17
# INFO:coolpuppy:('chr9', 'chr9'): 13
# INFO:coolpuppy:('chr10', 'chr10'): 11
# INFO:coolpuppy:('chr8', 'chr8'): 23
# INFO:coolpuppy:('chr7', 'chr7'): 9
# INFO:coolpuppy:('chr4', 'chr4'): 9
# INFO:coolpuppy:('chr6', 'chr6'): 8
# INFO:coolpuppy:('chr5', 'chr5'): 14
# INFO:coolpuppy:('chr13', 'chr13'): 4
# INFO:coolpuppy:('chr17', 'chr17'): 8
# INFO:coolpuppy:('chr16', 'chr16'): 12
# INFO:coolpuppy:('chr15', 'chr15'): 13
# INFO:coolpuppy:('chr14', 'chr14'): 3
# INFO:coolpuppy:('chr18', 'chr18'): 5
# INFO:coolpuppy:('chr19', 'chr19'): 6
# INFO:coolpuppy:('chr2', 'chr2'): 22
# INFO:coolpuppy:('chr3', 'chr3'): 7
# INFO:coolpuppy:('chr1', 'chr1'): 18
# INFO:coolpuppy:('chrX', 'chrX'): 4
# INFO:coolpuppy:Total number of piled up windows: 211
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
# INFO:coolpuppy:('chr12', 'chr12'): 99
# INFO:coolpuppy:('chr11', 'chr11'): 197
# INFO:coolpuppy:('chr9', 'chr9'): 172
# INFO:coolpuppy:('chr8', 'chr8'): 162
# INFO:coolpuppy:('chr10', 'chr10'): 132
# INFO:coolpuppy:('chr7', 'chr7'): 192
# INFO:coolpuppy:('chr4', 'chr4'): 157
# INFO:coolpuppy:('chr5', 'chr5'): 154
# INFO:coolpuppy:('chr13', 'chr13'): 128
# INFO:coolpuppy:('chr6', 'chr6'): 169
# INFO:coolpuppy:('chr16', 'chr16'): 87
# INFO:coolpuppy:('chr19', 'chr19'): 98
# INFO:coolpuppy:('chr15', 'chr15'): 126
# INFO:coolpuppy:('chr17', 'chr17'): 110
# INFO:coolpuppy:('chr3', 'chr3'): 185
# INFO:coolpuppy:('chr14', 'chr14'): 102
# INFO:coolpuppy:('chr2', 'chr2'): 253
# INFO:coolpuppy:('chr18', 'chr18'): 91
# INFO:coolpuppy:('chr1', 'chr1'): 193
# INFO:coolpuppy:('chrX', 'chrX'): 37
# INFO:coolpuppy:Total number of piled up windows: 2844
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
# INFO:coolpuppy:('chr12', 'chr12'): 99
# INFO:coolpuppy:('chr11', 'chr11'): 197
# INFO:coolpuppy:('chr10', 'chr10'): 132
# INFO:coolpuppy:('chr8', 'chr8'): 162
# INFO:coolpuppy:('chr9', 'chr9'): 172
# INFO:coolpuppy:('chr7', 'chr7'): 192
# INFO:coolpuppy:('chr6', 'chr6'): 169
# INFO:coolpuppy:('chr5', 'chr5'): 154
# INFO:coolpuppy:('chr4', 'chr4'): 157
# INFO:coolpuppy:('chr19', 'chr19'): 98
# INFO:coolpuppy:('chr13', 'chr13'): 128
# INFO:coolpuppy:('chr15', 'chr15'): 126
# INFO:coolpuppy:('chr18', 'chr18'): 91
# INFO:coolpuppy:('chr16', 'chr16'): 87
# INFO:coolpuppy:('chr14', 'chr14'): 102
# INFO:coolpuppy:('chr17', 'chr17'): 110
# INFO:coolpuppy:('chrX', 'chrX'): 37
# INFO:coolpuppy:('chr3', 'chr3'): 185
# INFO:coolpuppy:('chr1', 'chr1'): 193
# INFO:coolpuppy:('chr2', 'chr2'): 253
# INFO:coolpuppy:Total number of piled up windows: 2844
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
# INFO:coolpuppy:('chr12', 'chr12'): 972
# INFO:coolpuppy:('chr11', 'chr11'): 983
# INFO:coolpuppy:('chr9', 'chr9'): 1034
# INFO:coolpuppy:('chr7', 'chr7'): 1018
# INFO:coolpuppy:('chr8', 'chr8'): 971
# INFO:coolpuppy:('chr10', 'chr10'): 1204
# INFO:coolpuppy:('chr4', 'chr4'): 1119
# INFO:coolpuppy:('chr5', 'chr5'): 1201
# INFO:coolpuppy:('chr15', 'chr15'): 861
# INFO:coolpuppy:('chr13', 'chr13'): 1097
# INFO:coolpuppy:('chr14', 'chr14'): 974
# INFO:coolpuppy:('chr6', 'chr6'): 1280
# INFO:coolpuppy:('chr2', 'chr2'): 1733
# INFO:coolpuppy:('chr3', 'chr3'): 1559
# INFO:coolpuppy:('chr17', 'chr17'): 701
# INFO:coolpuppy:('chr16', 'chr16'): 869
# INFO:coolpuppy:('chr19', 'chr19'): 492
# INFO:coolpuppy:('chr1', 'chr1'): 1793
# INFO:coolpuppy:('chr18', 'chr18'): 772
# INFO:coolpuppy:('chrX', 'chrX'): 715
# INFO:coolpuppy:Total number of piled up windows: 21348
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical
# INFO:coolpuppy:('chr12', 'chr12'): 972
# INFO:coolpuppy:('chr11', 'chr11'): 983
# INFO:coolpuppy:('chr10', 'chr10'): 1204
# INFO:coolpuppy:('chr9', 'chr9'): 1034
# INFO:coolpuppy:('chr8', 'chr8'): 971
# INFO:coolpuppy:('chr7', 'chr7'): 1018
# INFO:coolpuppy:('chr6', 'chr6'): 1280
# INFO:coolpuppy:('chr5', 'chr5'): 1201
# INFO:coolpuppy:('chr4', 'chr4'): 1119
# INFO:coolpuppy:('chr13', 'chr13'): 1097
# INFO:coolpuppy:('chr15', 'chr15'): 861
# INFO:coolpuppy:('chr17', 'chr17'): 701
# INFO:coolpuppy:('chr19', 'chr19'): 492
# INFO:coolpuppy:('chr16', 'chr16'): 869
# INFO:coolpuppy:('chr18', 'chr18'): 772
# INFO:coolpuppy:('chr14', 'chr14'): 974
# INFO:coolpuppy:('chr3', 'chr3'): 1559
# INFO:coolpuppy:('chrX', 'chrX'): 715
# INFO:coolpuppy:('chr1', 'chr1'): 1793
# INFO:coolpuppy:('chr2', 'chr2'): 1733
# INFO:coolpuppy:Total number of piled up windows: 21348
# INFO:coolpuppy:Can't use symmetrical scale with linear. Plotting non-symmetrical
# INFO:coolpuppy:Can't set both vmin and vmax and get symmetrical scale. Plotting non-symmetrical

# %%
## ARCHIES BELOW THIS

# %%
for name in ['no', 'within', 'outside']:
    for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged']:
        pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                              loopDir, 'insulated_domain_ps_' + name,
                              minDist = 50, minDiag = 21, byDistance = False,
                              balance = 'weight', ooe = True)
        fileName = 'APA_' + name + '_ps_' + sample 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = figDir, fileName = fileName)
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.3, vmin = 0,
                fileDir = figDir, fileName = fileName + 'vminmax')
# DONE

# %%
for name in ['pe-pe_reg', 'pe-pe_str']:
    for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged']:
        pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                              loopDir, 'chromo_cons_annoHierarchy_' + name,
                              minDist = 50, minDiag = 21, byDistance = False,
                              balance = 'weight', ooe = True)
        fileName = 'APA_' + name + '_' + sample 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = figDir, fileName = fileName)
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = figDir, fileName = fileName + 'vminmax')
# DONE

# %%
for name in ['regulatory', 'structure', 'p-n', 'pe-pe', 'p-p', 'p-s', 'p-x', 'p-e',  'p-pe', 'x-x']:
    for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged', 'G1.A485.Merged']:
        pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                              loopDir, 'chromo_cons_annoHierarchy_' + name,
                              minDist = 50, minDiag = 21, byDistance = False,
                              balance = 'weight', ooe = True)
        fileName = 'APA_' + name + '_' + sample 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = figDir, fileName = fileName)
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = figDir, fileName = fileName + 'vminmax')
# DONE

# %%
for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged']:
    for name in ['structure', 'pe-pe']:
        for deg in ['UP', 'NO', 'DOWN']:
            pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                                  loopDir, 'chromo_cons_annoHierarchy_' + name + '_dTAGvsDMSO_' + deg + '_diff0.2',
                                  minDist = 50, minDiag = 21, byDistance = False,
                                  balance = 'weight', ooe = True)
            fileName = 'APA_dTAG_vs_DMSO_'+ deg + '_' + name + '_' + sample 
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                    fileDir = figDir, fileName = fileName)
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                    fileDir = figDir, fileName = fileName + 'vminmax')
# DONE

# %%
for sample in ['G1.DMSO.Merged', 'G1.A485.Merged']:
    for name in ['structure', 'pe-pe']:
        for deg in ['UP', 'NO', 'DOWN']:
            pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                                  loopDir, 'chromo_cons_annoHierarchy_' + name + '_A485vsDMSO_' + deg + '_diff0.2',
                                  minDist = 50, minDiag = 21, byDistance = False,
                                  balance = 'weight', ooe = True)
            fileName = 'APA_A485_vs_DMSO_'+ deg + '_' + name + '_' + sample 
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                    fileDir = figDir, fileName = fileName)
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                    fileDir = figDir, fileName = fileName + 'vminmax')
# DONE

# %%
for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged', 'G1.A485.Merged']:
    for name in ['all', 'regulatory', 'structure', 'pe-pe', 'p-p', 'p-e', 'e-e', 'x-x']:
        pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                              loopDir, 'chromo_cons_' + name,
                              minDist = 50, minDiag = 21, byDistance = False,
                              balance = 'weight', ooe = True)
        fileName = 'APA_' + name + '_' + sample 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = figDir, fileName = fileName)
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = figDir, fileName = fileName + 'vminmax')

# %%
for sample in ['G1.DMSO.Merged', 'G1.dTAG.Merged']:
    for name in ['all', 'regulatory', 'structure', 'pe-pe', 'p-p', 'p-e', 'e-e', 'x-x']:
        for deg in ['UP', 'NO', 'DOWN']:
            pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                                  loopDir, 'chromo_cons_dTAG_vs_DMSO_' + deg + '_' + name,
                                  minDist = 50, minDiag = 21, byDistance = False,
                                  balance = 'weight', ooe = True)
            fileName = 'APA_dTAG_vs_DMSO_'+ deg + '_' + name + '_' + sample 
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                    fileDir = figDir, fileName = fileName)
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                    fileDir = figDir, fileName = fileName + 'vminmax')

# %%
for sample in ['G1.DMSO.Merged', 'G1.A485.Merged']:
    for name in ['all', 'regulatory', 'structure', 'pe-pe', 'p-p', 'p-e', 'e-e', 'x-x']:
        for deg in ['UP', 'NO', 'DOWN']:
            pup = callAPAoverLoop(coolDir, sample + '_' + str(res) + 'kb',
                                  loopDir, 'chromo_cons_A485_vs_DMSO_' + deg + '_' + name,
                                  minDist = 50, minDiag = 21, byDistance = False,
                                  balance = 'weight', ooe = True)
            fileName = 'APA_A485_vs_DMSO_'+ deg + '_' + name + '_' + sample 
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                    fileDir = figDir, fileName = fileName)
            drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                    fileDir = figDir, fileName = fileName + 'vminmax')

# %%
for sample in ['HiChIP-H3K4me3_G1-RAD21-DMSO_rep1_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep1_5kb', 
               'HiChIP-H3K4me3_G1-RAD21-DMSO_rep2_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep2_5kb']:
    for loop in ['Tjian_chromosight_loops_regulatory', 'Tjian_chromosight_loops_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_structure',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_structure',
                 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.common_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.common_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_structure']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_G1DMSO, loop_all, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = figDir + '/chromo_cons.svg'
fg1.savefig(file1, format = 'svg')

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_specific.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_specific.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_specific.svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_specific.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %%
ctcf['quartile_FC_score'] = pd.qcut(ctcf['FC_score'], 4, labels=False) + 1
ctcf['peaks_importance'] = ctcf.apply(
    lambda x: 'Top by FC score' if x.quartile_FC_score==4 else 'Ordinary peaks', axis=1
)

# %%
# Select the CTCF sites that are in top quartile by both the ChIP-Seq data and motif score

sites = ctcf[ctcf['peaks_importance']=='Top by FC score']\
    .sort_values('FC_score', ascending=False)\
    .reset_index(drop=True)
sites.tail()

# %%
sites.to_csv('annotated_ctcf_sites.tsv', sep='\t', index=False, header=False) # Let's save to use in CLI

# %% [markdown]
# ## Loop pile up

# %% [markdown]
# ### Understanding how APA plot works

# %% [markdown]
# #### Comparing APA plotted in different resolution

# %%
# Merged loops
loop_file = "loop_calling_chromosight/MicroC_G1DMSO_Merged_chromosight_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

# Loading cool files
sample = "MicroC"
treatment = "G1DMSO"
resolution = 5
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_" + str(resolution) + "kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_" + str(resolution) + "kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

pup_DMSO_5kb = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, rescale=False, mindist=0 , by_distance=True, min_diag=21,
                     nproc=8)

resolution = 10
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_" + str(resolution) + "kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_" + str(resolution) + "kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

pup_DMSO_10kb = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, rescale=False, mindist=0 , by_distance=True, min_diag=11,
                     nproc=8)

resolution = 25
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_" + str(resolution) + "kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_" + str(resolution) + "kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

pup_DMSO_25kb = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, rescale=False, mindist=0 , by_distance=True, min_diag=5,
                     nproc=8)

# %%
#flank = resolution*1000*10
i = 8
fg1 = plotpup.plot(pup_DMSO_25kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 625/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1 = plotpup.plot(pup_DMSO_10kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 100/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)

# %% [markdown]
# #### Comparing APA plots with different color scales

# %%
#flank = resolution*1000*10
i = 2
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 3
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 4
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 5
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 6
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 7
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 8
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 9
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 10
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 15
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 20
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 40
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
#flank = resolution*1000*10
i = 80
fg1 = plotpup.plot(pup_DMSO_5kb,
             cmap='coolwarm',
             score = False, vmin = 0, vmax = 25/i,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)

# %%
sample = "MicroC"
treatment = "G1DMSO"
resolution = 5
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_" + str(resolution) + "kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_" + str(resolution) + "kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

pup_DMSO_5kb = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, rescale=False, mindist=50000 , by_distance=False, min_diag=21,
                     nproc=8)

# %%
i = 6
fg1 = plotpup.plot(pup_DMSO_5kb,
                     cmap='coolwarm',
                     score = False, vmin = 0, vmax = 25/i,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)

# %% [markdown]
# ### [Chromosight loops]

# %% [markdown]
# ### Comparing loops called in different resolution

# %% [markdown]
# #### DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg1 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False,  vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO.svg"
    file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg1.savefig(file1, format = 'svg')
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg3 = plotpup.plot(pup_DMSO,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
        file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg3.savefig(file3, format = 'svg')
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
     pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')

# %%
# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### DMSO/dTAG common loops

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb_common.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_common.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_common.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "_common.svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "_common.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - DMSO specific loops

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_specific.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_specific.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_specific.svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_specific.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - dTAG specific loops

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_specific.svg"
file2 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_specific.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_specific.svg"
    file4 = "pileup/APA_loop-Chromosight-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_specific.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### [Mustache loops]

# %% [markdown]
# ### Comparing loops called in different resolution

# %% [markdown]
# #### DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg1 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False,  vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO.svg"
    file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg1.savefig(file1, format = 'svg')
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg3 = plotpup.plot(pup_DMSO,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
        file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg3.savefig(file3, format = 'svg')
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')



# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### Merged loops - dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### common loops

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_25.10.5kb_common.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_common.svg"
file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_common.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "_common.svg"
    file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "_common.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### DMSO specific loops

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_25.10.5kb_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_specific.svg"
file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_specific.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_specific.svg"
    file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_specific.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# #### dTAG specific loops

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_mustache/" + sample + "_" + treatment + "_Merged_mustache_25.10.5kb_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_specific.svg"
file2 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_specific.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_specific.svg"
    file4 = "pileup/APA_loop-mustache-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_specific.svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### Comparing Chromosight vs Mustache

# %%
sample = "MicroC"
treatment = "G1DMSO"
loopCall = "chromosight"
note = "commonWithMustache"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_" + loopCall + "/" + sample + "_" + treatment + "_Merged_" + loopCall + "_25.10.5kb_" + note + ".bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_" + note + ".svg"
file2 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_" + note + ".svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_" + note + ".svg"
    file4 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_" + note + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %%
sample = "MicroC"
treatment = "G1DMSO"
loopCall = "chromosight"
note = "notCommonWithMustache"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_" + loopCall + "/" + sample + "_" + treatment + "_Merged_" + loopCall + "_25.10.5kb_" + note + ".bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_" + note + ".svg"
file2 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_" + note + ".svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_" + note + ".svg"
    file4 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_" + note + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %%
sample = "MicroC"
treatment = "G1DMSO"
loopCall = "mustache"
note = "notCommonWithChromosight"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_" + loopCall + "/" + sample + "_" + treatment + "_Merged_" + loopCall + "_25.10.5kb_" + note + ".bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb_" + note + ".svg"
file2 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb_" + note + ".svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')


# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + "kb_" + note + ".svg"
    file4 = "pileup/APA_loop-" + loopCall + "-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + "kb_" + note + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### [HiC-DC+ loops]

# %% [markdown]
# ### DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_hicdcp/" + sample + "_" + treatment + "_Merged_hicdcp_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg1 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False,  vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file1 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO.svg"
    file2 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg1.savefig(file1, format = 'svg')
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
    pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg3 = plotpup.plot(pup_DMSO,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file3 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
        file4 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg3.savefig(file3, format = 'svg')
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

for resolution in [25, 10, 5]:
    # Loading loops
    loop_file = "loop_calling_hicdcp/" + sample + "_" + treatment + "_Merged_hicdcp_" + str(resolution) + "kb.bedpe"
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
        
    # Pileup all loops longer than cutoff
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                         local=False, min_diag=21, by_distance=False,
                         nproc=8)
    
    # Make figure
    
    vmax = 25/6
    vmin = 0
    fg1 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False,  vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg2 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file1 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    file2 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG.svg"
    
    fg1.savefig(file1, format = 'svg')
    fg2.savefig(file2, format = 'svg')
    
    # Pileup loop subset by distance
    mindist = 0
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                              local=False, mindist=mindist , by_distance=True, min_diag=21,
                              nproc=8)
    
    # Make figure
    for i in [3, 5, 10, 20, 40]:
        vmax = 25/i
        vmin = 0
        fg3 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        fg4 = plotpup.plot(pup_dTAG,
                     cmap='coolwarm',
                     score = False, vmax = vmax, vmin = vmin,
                     scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
        file3 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        file4 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + str(resolution) + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
        fg3.savefig(file3, format = 'svg')
        fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### Merged loops - DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')

# Loading loops
loop_file = "loop_calling_hicdcp/" + sample + "_" + treatment + "_Merged_hicdcp_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')



# Pileup loop subset by distance
mindist = 0
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_DMSO,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ### Merged loops - dTAG

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_hicdcp/" + sample + "_" + treatment + "_Merged_hicdcp_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
file1 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')



# Pileup loop subset by distance
mindist = 0
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                      local=False, mindist=mindist , by_distance=True, min_diag=21,
                      nproc=8)

# Make figure
for i in [3, 5, 10, 20, 40]:
    vmax = 25/i
    vmin = 0
    fg3 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    fg4 = plotpup.plot(pup_dTAG,
                 cmap='coolwarm',
                 score = False, vmax = vmax, vmin = vmin,
                 scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
    file3 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    file4 = "pileup/APA_loop-hicdcp-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_split_" + str(i) + ".svg"
    fg3.savefig(file3, format = 'svg')
    fg4.savefig(file4, format = 'svg')

# %% [markdown]
# ## Chromosight 2

# %% [markdown]
# #### DMSO

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

clr_DMSO.bins()[:3000].weight.max()

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight_trial2/" + sample + "_" + treatment + "_Merged_chromosight_25.10.5kb.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8, clr_weight_name = "weight")
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8, clr_weight_name = "weight")

# %%
# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm', vmin = vmin, vmax = vmax,
             score = False, 
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_DMSO, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm', vmin = vmin, vmax = vmax,
             score = False, 
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_dTAG, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
file1 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.DMSO_" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25.10.5" + "kb_on_MicroC.G1.dTAG_" + str(min) + "kb.svg"
#fg1.savefig(file1, format = 'svg')
#fg2.savefig(file2, format = 'svg')

# %% [markdown]
# #### DMSO specific

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight_trial2/" + sample + "_" + treatment + "_chromosight_25kbexpanded_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_DMSO, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_dTAG, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
file1 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_specific_DMSO" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_specific_dTAG" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')

# %% [markdown]
# #### DMSO/dTAG common

# %%
sample = "MicroC"
treatment = "G1DMSO"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight_trial2/" + sample + "_" + treatment + "_chromosight_25kbexpanded_common.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_DMSO, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_dTAG, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
file1 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_common_DMSO" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_common_dTAG" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')

# %% [markdown]
# #### dTAG specific

# %%
sample = "MicroC"
treatment = "G1dTAG"

# Loading cool files
cool_file_DMSO = "data/mcool/" + sample + "_G1DMSO_Merged_5kbcorr.cool"
cool_file_dTAG = "data/mcool/" + sample + "_G1dTAG_Merged_5kbcorr.cool"
clr_DMSO = cooler.Cooler(f'{cool_file_DMSO}')
clr_dTAG = cooler.Cooler(f'{cool_file_dTAG}')

# Loading loops
loop_file = "loop_calling_chromosight_trial2/" + sample + "_" + treatment + "_chromosight_25kbexpanded_specific.bedpe"
loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']

min = 50
# Pileup all loops longer than cutoff
pup_DMSO = coolpup.pileup(clr_DMSO, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)
pup_dTAG = coolpup.pileup(clr_dTAG, loop, features_format='bedpe',
                     local=False, min_diag=21, by_distance=False, mindist=min*1000,
                     nproc=8)

# Make figure

vmax = 25/6
vmin = 0
fg1 = plotpup.plot(pup_DMSO,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg1.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_DMSO, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
fg2 = plotpup.plot(pup_dTAG,
             cmap='coolwarm',
             score = False, vmax = vmax, vmin = vmin,
             scale='linear', sym=True, height=1, plot_ticks=True, font_scale = 0.8)
fg2.ax.text(
            s= "corner score: " + str(round(get_corner_score(pup_dTAG, flank = 2)[0], 2)),
            y=0.9*20,
            x=0.9*20,
            ha="right",
            va="top",
            size=4,
        )
file1 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_specific_DMSO" + str(min) + "kb.svg"
file2 = "pileup/APA_loop-Chromosight_trial2-" + sample + "-" + treatment + "-" + "25kbexpanded_specific_dTAG" + str(min) + "kb.svg"
fg1.savefig(file1, format = 'svg')
fg2.savefig(file2, format = 'svg')

# %% [markdown]
# #### dTAG

# %% [markdown]
# ## Generalization

# %%
import copy

def callAPAoverLoop(coolFileDir, coolFileName, loopFileDir, loopFileName, minDist, minDiag, byDistance, balance, ooe):
    # minDist = minimun distance in kb to plot in APA
    # Load cool file
    cool_file = coolFileDir + '/' + coolFileName + '.cool'
    clr = cooler.Cooler(f'{cool_file}')
    # Load loop file
    loop_file = loopFileDir + '/' + loopFileName + '.bedpe'
    loop = pd.read_csv(loop_file, sep = '\t', header = None).iloc[:, :6]
    loop.columns = ['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']
    # Load expected table
    exp_file = coolFileDir + '/' + coolFileName + '_exp.tsv'
    exp_df = pd.read_csv(exp_file, delimiter='\t')

    # Pileup
    if ooe:
        pup = coolpup.pileup(clr, loop, features_format = 'bedpe',
                             min_diag = minDiag, mindist = minDist*1000, by_distance = byDistance,
                             nproc = 12, 
                             clr_weight_name = balance,
                             ooe = True, expected_df = exp_df)
    else:
         pup = coolpup.pileup(clr, loop, features_format = 'bedpe',
                             min_diag = minDiag, mindist = minDist*1000, by_distance = byDistance,
                             nproc = 12, 
                             clr_weight_name = balance,
                             ooe = False)       

    return pup

def get_corner_score(pup, flank = 1):
    amap = pup["data"][0]
    c = amap.shape[0] / (flank*2 + 1)
    c = int(c)
    central = np.nanmean(amap[flank*c:-flank:c, flank*c:-flank*c])
    topRight = np.nanmean(amap[:c, -c:])
    cornerScore = central/topRight
    return cornerScore, central, topRight, 


def drawAPA(pup, scale, colormap, vmax, vmin, fileDir, fileName):
    puptemp = copy.deepcopy(pup)
    if scale == 'log10':
        puptemp.data[0] = np.log10(puptemp.data[0])

    # Make figure
    # Enrichment score is calculated by ratio of C(obs/exp) to R (obs/exp) before doing any form of log transform
    if vmax == False:
        fg1 = plotpup.plot(puptemp,
                           cmap = colormap,
                           score = False, 
                           scale = 'linear', height = 1, plot_ticks = True, font_scale = 0.8)
        fg1.ax.text(s= "corner score: " + str(round(get_corner_score(pup, flank = 2)[0], 2)),
                   x=0.9*20,  y=0.9*20,
                   va="top", ha="right",
                   size=4)
    else:
        fg1 = plotpup.plot(puptemp,
                   cmap = colormap,
                   score = False, vmax = vmax, vmin = vmin,
                   scale = 'linear', height = 1, plot_ticks = True, font_scale = 0.8)
        fg1.ax.text(s= "corner score: " + str(round(get_corner_score(pup, flank = 2)[0], 2)),
                   x=0.9*20,  y=0.9*20,
                   va="top", ha="right",
                   size=4)
    file = fileDir + '/' + fileName + '.svg'
    fg1.savefig(file, format = 'svg')
    return True

# %%
for sample in ['MicroC_G1-RAD21-DMSO_pool_5kb', 'MicroC_G1-RAD21-dTAG_pool_5kb']:
    for loop in ['MicroC_G1-RAD21-DMSO_pool_chromosight_allRes', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_DMSOspec', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_dTAGcom', 
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_25kbExpd_dTAGspec',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes',
                 'Tjian_chromosight_loops']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['GSE178982_Async-RAD21-UT_pool_5kb', 'GSE178982_Async-RAD21-AID_pool_5kb']:
    for loop in ['MicroC_G1-RAD21-DMSO_pool_chromosight_allRes', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_DMSOspec', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_dTAGcom', 
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_25kbExpd_dTAGspec',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes',
                 'Tjian_chromosight_loops']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['HiChIP-H3K4me3_Async-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_Async-RAD21-dTAG_pool_5kb',
               'HiChIP-H3K4me3_G1-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_pool_5kb']:
    for loop in ['MicroC_G1-RAD21-DMSO_pool_chromosight_allRes', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_DMSOspec', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_dTAGcom', 
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_25kbExpd_dTAGspec',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes',
                 'Tjian_chromosight_loops']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['HiChIP-H3K4me3_G1-RAD21-DMSO_rep1_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep1_5kb', 
               'HiChIP-H3K4me3_G1-RAD21-DMSO_rep2_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep2_5kb']:
    for loop in ['MicroC_G1-RAD21-DMSO_pool_chromosight_allRes', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_DMSOspec', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_25kbExpd_dTAGcom', 
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_25kbExpd_dTAGspec',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes',
                 'Tjian_chromosight_loops']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['MicroC_G1-RAD21-DMSO_pool_5kb', 'MicroC_G1-RAD21-dTAG_pool_5kb',
               'GSE178982_Async-RAD21-UT_pool_5kb', 'GSE178982_Async-RAD21-AID_pool_5kb',
               'HiChIP-H3K4me3_Async-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_Async-RAD21-dTAG_pool_5kb',
               'HiChIP-H3K4me3_G1-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_pool_5kb']:
    for loop in ['HiChIP_HiCDCP_10kb.resCom.G1.DMSO', 'HiChIP_HiCDCP_10kb.resCom.G1.DMSOspecific',
                 'HiChIP_HiCDCP_10kb.resCom.G1.common', 'HiChIP_HiCDCP_10kb.resCom.G1.dTAGspecific',
                 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['MicroC_G1-RAD21-DMSO_pool_5kb', 'MicroC_G1-RAD21-dTAG_pool_5kb',
              'GSE178982_Async-RAD21-UT_pool_5kb', 'GSE178982_Async-RAD21-AID_pool_5kb',
               'HiChIP-H3K4me3_G1-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_pool_5kb',
              'HiChIP-H3K4me3_Async-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_Async-RAD21-dTAG_pool_5kb']:
    for loop in ['MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_structure', 
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_regulatory']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = False, vmin = False,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['MicroC_G1-RAD21-DMSO_pool_5kb', 'MicroC_G1-RAD21-dTAG_pool_5kb',
              'GSE178982_Async-RAD21-UT_pool_5kb', 'GSE178982_Async-RAD21-AID_pool_5kb',
               'HiChIP-H3K4me3_G1-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_pool_5kb',
              'HiChIP-H3K4me3_Async-RAD21-DMSO_pool_5kb', 'HiChIP-H3K4me3_Async-RAD21-dTAG_pool_5kb']:
    for loop in ['Tjian_chromosight_loops_regulatory', 'Tjian_chromosight_loops_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_structure',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_structure',
                 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.common_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.common_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_structure']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)

# %%
for sample in ['HiChIP-H3K4me3_G1-RAD21-DMSO_rep1_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep1_5kb', 
               'HiChIP-H3K4me3_G1-RAD21-DMSO_rep2_5kb', 'HiChIP-H3K4me3_G1-RAD21-dTAG_rep2_5kb']:
    for loop in ['Tjian_chromosight_loops_regulatory', 'Tjian_chromosight_loops_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_structure',
                 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_regulatory', 'MicroC_G1-RAD21-DMSO_pool_chromosight_allRes_dTAGcom_structure',
                 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_regulatory', 'MicroC_G1-RAD21-dTAG_pool_chromosight_allRes_structure',
                 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1DMSO_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_regulatory', 'MicroC_G1dTAG_Merged_nb_vardisp_spline_5kb_0_2000000_count-based_qval0.05_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.DMSO_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.common_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.common_structure',
                 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_regulatory', 'HiChIP_HiCDCP_10kb.resCom.G1.dTAG_structure']:
        pup = callAPAoverLoop('../data/cool', sample, 
                         '../data/loop', loop,
                         minDist = 50, minDiag = 21, byDistance = False,
                         balance = 'weight', ooe = True)
        fileName = 'APA_' + sample + '_' + loop 
        drawAPA(pup, scale = 'log10', colormap = 'coolwarm', vmax = 0.4, vmin = -0.1,
                fileDir = 'pileup_trial2', fileName = fileName)
