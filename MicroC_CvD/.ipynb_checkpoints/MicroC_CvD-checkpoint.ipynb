# %% [markdown]
# # Micro-C Contact vs Distance plot
#
# Reference (https://cooltools.readthedocs.io/en/latest/notebooks/contacts_vs_distance.html)

# %%
# INSTALL REQUIRED PACKAGES

#!pip install cooltools==0.7.0
#!pip install seaborn
#!pip install cooler

# %%
# Standard library imports
import os
import warnings
from itertools import combinations
from multiprocessing import Pool
import subprocess

# Third-party imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import bioframe
import cooler
import cooltools
from packaging import version

# Jupyter magic (only in notebooks)
# %matplotlib inline

# ------------------------------------------------------------------------------
# Configuration
# ------------------------------------------------------------------------------

# Suppress non-critical warnings
warnings.filterwarnings('ignore')

# Determine number of CPUs
num_cpus = os.cpu_count() or 1

print(f'Using {num_cpus} CPU core{'s' if num_cpus > 1 else ''}.')
# Out:
# Using 10 CPU cores.

# %% [markdown]
# ## Parameters

# %%
REFDIR = 'reference'
SCRDIR = 'script'

# Use bioframe to fetch the genomic features from the UCSC.
mm10_chromsizes = bioframe.fetch_chromsizes('mm10')
mm10_cens = pd.read_csv(f'{REFDIR}/mm10/mm10.centromere.txt', sep = '\t')

# create a view with chromosome arms using chromosome sizes and definition of centromeres
mm10_arms = bioframe.make_chromarms(mm10_chromsizes,  mm10_cens)

# %% [markdown]
# ## Calculating CvD with downsampled matrix
# All samples will be downsampled to same readcount and KR normalized for proper comparison.

# %%
def process_cvd(MCOOLDIR, COOLDIR, OUTDIR, NAME, RES, DSCOUNT, mm10_arms, num_cpus, WORKDIR):
    '''
    1. Subsamples the merged .mcool at resolution RES to DSCOUNT reads (if needed)
    2. KR-normalizes the subsampled matrix via normCool.sh (if needed)
    3. Computes the expected cis-decay curve, smooths it, masks dist<2, 
       merges duplicates, and writes out both the merged curve and its log-log derivative.

    Parameters
    ----------
    MCOOLDIR : str
        Path to the pooled .mcool file (expects {NAME}_allRes.mcool).
    COOLDIR : str
        Directory for normalized/downsamped .cool files.
    OUTDIR : str
        Directory for output TSVs.
    NAME : str
        Sample name prefix.
    RES : int
        Resolution in bp.
    DSCOUNT : int
        Number of contacts to subsample (e.g. 5_000_000).
    mm10_arms : pd.DataFrame
        A view_df defining chromosome arms.
    num_cpus : int
        Number of processes to use for cooltools.sample and expected_cis.
    WORKDIR : str
        Directory containing `normCool.sh`.
    '''
    os.makedirs(OUTDIR, exist_ok=True)

    # paths
    subsampled = f'{COOLDIR}/{NAME}_{RES}bp_downsampled-{DSCOUNT//1_000_000}M_KR.cool'

    # calculate subsampling fraction
    pre_norm = cooler.Cooler(f'{COOLDIR}/{NAME}_{RES}bp_KR.cool')
    frac = DSCOUNT / pre_norm.info['sum']
    print(f'prenorm: {pre_norm.info['sum']}')
    print(f'sampling fraction: {frac}')
    
    # 1) subsample if needed
    if not os.path.exists(subsampled):
        print(f'sampling to {subsampled}')
        mc = cooler.Cooler(f'{MCOOLDIR}/{NAME}_allRes.mcool::/resolutions/{RES}')
        cooltools.sample(mc,
                         out_clr_path=subsampled,
                         frac=frac,
                         nproc=num_cpus)
        
        script = os.path.join(WORKDIR, 'normCool.sh')
        print(f'normalizing {subsampled}')
        subprocess.run([script, subsampled, str(num_cpus)], check=True)
    else:
        print(f'skipping sample (exists): {subsampled}')

    # 2) compute expected cis-decay curve
    clr = cooler.Cooler(subsampled)
    cvd = cooltools.expected_cis(
        clr=clr,
        view_df=mm10_arms,
        smooth=True,
        aggregate_smoothed=True,
        smooth_sigma=0.1,
        nproc=num_cpus
    )

    # write smoothed curve
    out_smooth = os.path.join(
        OUTDIR,
        f'{NAME}_{RES}bp_downsampled-{DSCOUNT//1_000_000}M_cvd_smooth.tsv'
    )
    cvd.to_csv(out_smooth, sep='\t', index=False)

    # mask dist<2
    mask = cvd['dist'] < 2
    cvd.loc[mask, ['balanced.avg.smoothed',
                   'balanced.avg.smoothed.agg']] = np.nan

    # merge duplicates & save
    cvd_merged = cvd.drop_duplicates(subset=['dist'])[
        ['dist_bp', 'balanced.avg.smoothed.agg']
    ]
    out_merged = os.path.join(
        OUTDIR,
        f'{NAME}_{RES}bp_downsampled-{DSCOUNT//1_000_000}M_cvd_smooth_merged.tsv'
    )
    cvd_merged.to_csv(out_merged, sep='\t', index=False)

    # derivative in log-log space & save
    der = np.gradient(
        np.log(cvd_merged['balanced.avg.smoothed.agg']),
        np.log(cvd_merged['dist_bp'])
    )
    der_df = pd.DataFrame({'derivative': der})
    out_deriv = os.path.join(
        OUTDIR,
        f'{NAME}_{RES}bp_downsampled-{DSCOUNT//1_000_000}M_cvd_smooth_merged_derivative.tsv'
    )
    der_df.to_csv(out_deriv, sep='\t', index=False)

    print('Done.')
    return cvd, cvd_merged, der_df

# %%
names = [
    'G1DMSO_pooled',
    'G1dTAG_pooled',
    'G1A485_pooled',
    'GSE178982_AsyncUT_pooled',
    'GSE178982_AsyncAID_pooled'
]

for name in names:
    print(f"Processing {name}…")
    process_cvd(
        MCOOLDIR    = '../data/mcool_pooled',
        COOLDIR     = '../data/cool_norm_pooled',
        OUTDIR      = '../data/cvd',
        NAME        = name,
        RES         = 1000,
        DSCOUNT     = 300_000_000,
        mm10_arms   = mm10_arms,
        num_cpus    = num_cpus,
        WORKDIR     = SCRDIR
    )
# Out:
# INFO:root:creating a Pool of 10 workers
# Processing G1DMSO_pooled…
# prenorm: 1387522117.0
# sampling fraction: 0.21621276974570922
# sampling to ../data/cool_norm_pooled/G1DMSO_pooled_1000bp_downsampled-300M_KR.cool
# normalizing ../data/cool_norm_pooled/G1DMSO_pooled_1000bp_downsampled-300M_KR.cool
# INFO:cooler.cli.balance:Balancing "../data/cool_norm_pooled/G1DMSO_pooled_1000bp_downsampled-300M_KR.cool"
# INFO:cooler.balance:variance is 19269.25735339472
# INFO:cooler.balance:variance is 8704.289939100387
# INFO:cooler.balance:variance is 2599.7889517330455
# INFO:cooler.balance:variance is 4173.937561209409
# INFO:cooler.balance:variance is 1260.2737061540067
# INFO:cooler.balance:variance is 2046.703383754511
# INFO:cooler.balance:variance is 702.3725307028188
# INFO:cooler.balance:variance is 1039.6095829031628
# INFO:cooler.balance:variance is 416.8074917404319
# INFO:cooler.balance:variance is 545.2793512280296
# INFO:cooler.balance:variance is 251.6071623936816
# INFO:cooler.balance:variance is 293.18185218412856
# INFO:cooler.balance:variance is 151.75276459543286
# INFO:cooler.balance:variance is 160.57867411932236
# INFO:cooler.balance:variance is 90.97064169501076
# INFO:cooler.balance:variance is 89.17148932577115
# INFO:cooler.balance:variance is 54.1690429575004
# INFO:cooler.balance:variance is 50.032951233984285
# INFO:cooler.balance:variance is 32.06554388132565
# INFO:cooler.balance:variance is 28.292814300436664
# INFO:cooler.balance:variance is 18.890387204285073
# INFO:cooler.balance:variance is 16.09402028382234
# INFO:cooler.balance:variance is 11.086678940141628
# INFO:cooler.balance:variance is 9.196096198007034
# INFO:cooler.balance:variance is 6.487685690598527
# INFO:cooler.balance:variance is 5.2726136540609385
# INFO:cooler.balance:variance is 3.78791305957811
# INFO:cooler.balance:variance is 3.0309421118231863
# INFO:cooler.balance:variance is 2.2078091462606575
# INFO:cooler.balance:variance is 1.7457797423150423
# INFO:cooler.balance:variance is 1.2851431420822346
# INFO:cooler.balance:variance is 1.0070630979289026
# INFO:cooler.balance:variance is 0.74731875939275
# INFO:cooler.balance:variance is 0.5815988660615923
# INFO:cooler.balance:variance is 0.43423885887628016
# INFO:cooler.balance:variance is 0.336179655134571
# INFO:cooler.balance:variance is 0.2521734225714788
# INFO:cooler.balance:variance is 0.1944508926438469
# INFO:cooler.balance:variance is 0.14637884115762348
# INFO:cooler.balance:variance is 0.1125304939511621
# INFO:cooler.balance:variance is 0.08493990270939152
# INFO:cooler.balance:variance is 0.06514780394642011
# INFO:cooler.balance:variance is 0.04927592111726191
# INFO:cooler.balance:variance is 0.03772754748647481
# INFO:cooler.balance:variance is 0.028580771525199968
# INFO:cooler.balance:variance is 0.0218532517552634
# INFO:cooler.balance:variance is 0.016574850193079183
# INFO:cooler.balance:variance is 0.012660444795047066
# INFO:cooler.balance:variance is 0.009611189243140448
# INFO:cooler.balance:variance is 0.00733566474788875
# INFO:cooler.balance:variance is 0.005572732231427984
# INFO:cooler.balance:variance is 0.004250832823205646
# INFO:cooler.balance:variance is 0.003230960227167648
# INFO:cooler.balance:variance is 0.002463441456969958
# INFO:cooler.balance:variance is 0.0018731568867542772
# INFO:cooler.balance:variance is 0.001427697555885348
# INFO:cooler.balance:variance is 0.001085927647152902
# INFO:cooler.balance:variance is 0.0008274654779077683
# INFO:cooler.balance:variance is 0.0006295289087393394
# INFO:cooler.balance:variance is 0.00047959939213791257
# INFO:cooler.balance:variance is 0.00036493997422226167
# INFO:cooler.balance:variance is 0.0002779834239924448
# INFO:cooler.balance:variance is 0.00021155357859854596
# INFO:cooler.balance:variance is 0.00016112688368594215
# INFO:cooler.balance:variance is 0.00012263492425142671
# INFO:cooler.balance:variance is 9.339505421016921e-05
# INFO:cooler.balance:variance is 7.108927316884725e-05
# INFO:cooler.balance:variance is 5.41358462581555e-05
# INFO:cooler.balance:variance is 4.120890282786582e-05
# INFO:cooler.balance:variance is 3.137978409877764e-05
# INFO:cooler.balance:variance is 2.3887781735278585e-05
# INFO:cooler.balance:variance is 1.818938496651467e-05
# INFO:cooler.balance:variance is 1.3847103240315632e-05
# INFO:cooler.balance:variance is 1.0543587593516955e-05
# INFO:cooler.balance:variance is 8.026769409628778e-06
# INFO:root:creating a Pool of 10 workers
# INFO:root:creating a Pool of 10 workers
# Done.
# Processing G1dTAG_pooled…
# prenorm: 1236239723.0
# sampling fraction: 0.24267138033065777
# sampling to ../data/cool_norm_pooled/G1dTAG_pooled_1000bp_downsampled-300M_KR.cool
# normalizing ../data/cool_norm_pooled/G1dTAG_pooled_1000bp_downsampled-300M_KR.cool
# INFO:cooler.cli.balance:Balancing "../data/cool_norm_pooled/G1dTAG_pooled_1000bp_downsampled-300M_KR.cool"
# INFO:cooler.balance:variance is 93514.96799323727
# INFO:cooler.balance:variance is 4003.7700768558057
# INFO:cooler.balance:variance is 982.4550812370488
# INFO:cooler.balance:variance is 1594.0050313942093
# INFO:cooler.balance:variance is 480.685888556365
# INFO:cooler.balance:variance is 709.9711603816203
# INFO:cooler.balance:variance is 263.4042241403402
# INFO:cooler.balance:variance is 335.58033404062763
# INFO:cooler.balance:variance is 148.19301700314438
# INFO:cooler.balance:variance is 164.7929389243706
# INFO:cooler.balance:variance is 83.2063566361227
# INFO:cooler.balance:variance is 83.03360621043974
# INFO:cooler.balance:variance is 46.31760570803385
# INFO:cooler.balance:variance is 42.59008442905958
# INFO:cooler.balance:variance is 25.561645647289968
# INFO:cooler.balance:variance is 22.122097782947545
# INFO:cooler.balance:variance is 14.007538974847384
# INFO:cooler.balance:variance is 11.594491346729805
# INFO:cooler.balance:variance is 7.634581467656066
# INFO:cooler.balance:variance is 6.116436518500427
# INFO:cooler.balance:variance is 4.144387469620974
# INFO:cooler.balance:variance is 3.2418775067934447
# INFO:cooler.balance:variance is 2.2431163322699184
# INFO:cooler.balance:variance is 1.7242258471716045
# INFO:cooler.balance:variance is 1.2114548839640586
# INFO:cooler.balance:variance is 0.9193740123656566
# INFO:cooler.balance:variance is 0.653255496652782
# INFO:cooler.balance:variance is 0.491134789536689
# INFO:cooler.balance:variance is 0.35185759397242794
# INFO:cooler.balance:variance is 0.26272871367488737
# INFO:cooler.balance:variance is 0.1893631943867123
# INFO:cooler.balance:variance is 0.1406880419223822
# INFO:cooler.balance:variance is 0.10185172415969397
# INFO:cooler.balance:variance is 0.0753937179099617
# INFO:cooler.balance:variance is 0.05475924264725731
# INFO:cooler.balance:variance is 0.04042565040835975
# INFO:cooler.balance:variance is 0.029431666773082194
# INFO:cooler.balance:variance is 0.02168504487777258
# INFO:cooler.balance:variance is 0.01581533195223591
# INFO:cooler.balance:variance is 0.011635869917296733
# INFO:cooler.balance:variance is 0.008497182071166951
# INFO:cooler.balance:variance is 0.006245084522352686
# INFO:cooler.balance:variance is 0.004564825641338825
# INFO:cooler.balance:variance is 0.0033523799917754447
# INFO:cooler.balance:variance is 0.002452110850504645
# INFO:cooler.balance:variance is 0.0017998017220336472
# INFO:cooler.balance:variance is 0.0013171420938967368
# INFO:cooler.balance:variance is 0.0009663589404348901
# INFO:cooler.balance:variance is 0.0007074714181058708
# INFO:cooler.balance:variance is 0.0005189005385533164
# INFO:cooler.balance:variance is 0.00037999156321344966
# INFO:cooler.balance:variance is 0.0002786465989991008
# INFO:cooler.balance:variance is 0.0002040945264853638
# INFO:cooler.balance:variance is 0.00014963784716529635
# INFO:cooler.balance:variance is 0.00010961843833645252
# INFO:cooler.balance:variance is 8.036053463913893e-05
# INFO:cooler.balance:variance is 5.8875208424045216e-05
# INFO:cooler.balance:variance is 4.31573258753174e-05
# INFO:cooler.balance:variance is 3.162125522306421e-05
# INFO:cooler.balance:variance is 2.3177899957269574e-05
# INFO:cooler.balance:variance is 1.6983389945425135e-05
# INFO:cooler.balance:variance is 1.2448000792092503e-05
# INFO:cooler.balance:variance is 9.12155423004583e-06
# INFO:root:creating a Pool of 10 workers
# INFO:root:creating a Pool of 10 workers
# Done.
# Processing G1A485_pooled…
# prenorm: 1798711513.0
# sampling fraction: 0.16678605648086492
# sampling to ../data/cool_norm_pooled/G1A485_pooled_1000bp_downsampled-300M_KR.cool
# normalizing ../data/cool_norm_pooled/G1A485_pooled_1000bp_downsampled-300M_KR.cool
# INFO:cooler.cli.balance:Balancing "../data/cool_norm_pooled/G1A485_pooled_1000bp_downsampled-300M_KR.cool"
# INFO:cooler.balance:variance is 48870.789731506295
# INFO:cooler.balance:variance is 5518.36546215804
# INFO:cooler.balance:variance is 1559.7893265834355
# INFO:cooler.balance:variance is 1844.0038529490473
# INFO:cooler.balance:variance is 578.8677788134617
# INFO:cooler.balance:variance is 669.2959445458052
# INFO:cooler.balance:variance is 254.9711661613593
# INFO:cooler.balance:variance is 260.77079575729243
# INFO:cooler.balance:variance is 117.88264008849424
# INFO:cooler.balance:variance is 106.8211305748193
# INFO:cooler.balance:variance is 54.782094299735384
# INFO:cooler.balance:variance is 45.2241367102713
# INFO:cooler.balance:variance is 25.315735417867767
# INFO:cooler.balance:variance is 19.559986094792585
# INFO:cooler.balance:variance is 11.62071925202241
# INFO:cooler.balance:variance is 8.57849526073353
# INFO:cooler.balance:variance is 5.305145953779798
# INFO:cooler.balance:variance is 3.796828839917606
# INFO:cooler.balance:variance is 2.412240731659263
# INFO:cooler.balance:variance is 1.6906664214807985
# INFO:cooler.balance:variance is 1.093776134773912
# INFO:cooler.balance:variance is 0.755872536236069
# INFO:cooler.balance:variance is 0.4950045030832614
# INFO:cooler.balance:variance is 0.3388586986303536
# INFO:cooler.balance:variance is 0.2237363777409832
# INFO:cooler.balance:variance is 0.152190414514824
# INFO:cooler.balance:variance is 0.10104132839750721
# INFO:cooler.balance:variance is 0.06843844401007143
# INFO:cooler.balance:variance is 0.045606193643409086
# INFO:cooler.balance:variance is 0.030802504721003193
# INFO:cooler.balance:variance is 0.020577662931242073
# INFO:cooler.balance:variance is 0.013871686851354606
# INFO:cooler.balance:variance is 0.009282650383327425
# INFO:cooler.balance:variance is 0.006249584062704548
# INFO:cooler.balance:variance is 0.004186860477253485
# INFO:cooler.balance:variance is 0.0028164216893512874
# INFO:cooler.balance:variance is 0.0018882928895688246
# INFO:cooler.balance:variance is 0.001269497716245819
# INFO:cooler.balance:variance is 0.0008515885343154126
# INFO:cooler.balance:variance is 0.0005723058947369561
# INFO:cooler.balance:variance is 0.00038404257488070795
# INFO:cooler.balance:variance is 0.0002580291305212291
# INFO:cooler.balance:variance is 0.00017319043938110603
# INFO:cooler.balance:variance is 0.00011634320065583328
# INFO:cooler.balance:variance is 7.810285504571944e-05
# INFO:cooler.balance:variance is 5.2460960470874975e-05
# INFO:cooler.balance:variance is 3.5221701573430624e-05
# INFO:cooler.balance:variance is 2.365637523948639e-05
# INFO:cooler.balance:variance is 1.588382945808038e-05
# INFO:cooler.balance:variance is 1.0667740654784763e-05
# INFO:cooler.balance:variance is 7.163116499088343e-06
# INFO:root:creating a Pool of 10 workers
# INFO:root:creating a Pool of 10 workers
# Done.
# Processing GSE178982_AsyncUT_pooled…
# prenorm: 601264599.0
# sampling fraction: 0.4989483839543329
# sampling to ../data/cool_norm_pooled/GSE178982_AsyncUT_pooled_1000bp_downsampled-300M_KR.cool
# normalizing ../data/cool_norm_pooled/GSE178982_AsyncUT_pooled_1000bp_downsampled-300M_KR.cool
# INFO:cooler.cli.balance:Balancing "../data/cool_norm_pooled/GSE178982_AsyncUT_pooled_1000bp_downsampled-300M_KR.cool"
# INFO:cooler.balance:variance is 770978.5036486239
# INFO:cooler.balance:variance is 9302.415593120215
# INFO:cooler.balance:variance is 5015.958420804777
# INFO:cooler.balance:variance is 5433.101900412451
# INFO:cooler.balance:variance is 2730.6780770134515
# INFO:cooler.balance:variance is 2770.595673944817
# INFO:cooler.balance:variance is 1381.7090447588614
# INFO:cooler.balance:variance is 1345.2758879656487
# INFO:cooler.balance:variance is 692.0793802963112
# INFO:cooler.balance:variance is 648.3486507841446
# INFO:cooler.balance:variance is 349.965879810914
# INFO:cooler.balance:variance is 315.24444815794686
# INFO:cooler.balance:variance is 179.28597940560434
# INFO:cooler.balance:variance is 155.4972775357999
# INFO:cooler.balance:variance is 92.91196360535264
# INFO:cooler.balance:variance is 77.87309823717132
# INFO:cooler.balance:variance is 48.58828190752461
# INFO:cooler.balance:variance is 39.54808436217676
# INFO:cooler.balance:variance is 25.58385405109494
# INFO:cooler.balance:variance is 20.32833160146272
# INFO:cooler.balance:variance is 13.540432129356061
# INFO:cooler.balance:variance is 10.554192780075349
# INFO:cooler.balance:variance is 7.19424746182564
# INFO:cooler.balance:variance is 5.524188768770928
# INFO:cooler.balance:variance is 3.8337891958260357
# INFO:cooler.balance:variance is 2.9101634474257048
# INFO:cooler.balance:variance is 2.047726796014235
# INFO:cooler.balance:variance is 1.5409155526512928
# INFO:cooler.balance:variance is 1.0957289212335108
# INFO:cooler.balance:variance is 0.8191702756154946
# INFO:cooler.balance:variance is 0.5871664287089947
# INFO:cooler.balance:variance is 0.436841201122425
# INFO:cooler.balance:variance is 0.31500972862113485
# INFO:cooler.balance:variance is 0.23352273040193605
# INFO:cooler.balance:variance is 0.16915960173092104
# INFO:cooler.balance:variance is 0.1250716790044516
# INFO:cooler.balance:variance is 0.09090859775349118
# INFO:cooler.balance:variance is 0.06708622008034788
# INFO:cooler.balance:variance is 0.04888660767413715
# INFO:cooler.balance:variance is 0.03602576410729701
# INFO:cooler.balance:variance is 0.026302935672648936
# INFO:cooler.balance:variance is 0.019363826637639567
# INFO:cooler.balance:variance is 0.014158255305391032
# INFO:cooler.balance:variance is 0.01041559692164762
# INFO:cooler.balance:variance is 0.007623868271546802
# INFO:cooler.balance:variance is 0.0056056723280784445
# INFO:cooler.balance:variance is 0.004106536815403261
# INFO:cooler.balance:variance is 0.0030183647757715585
# INFO:cooler.balance:variance is 0.0022125332781409183
# INFO:cooler.balance:variance is 0.0016258374487258208
# INFO:cooler.balance:variance is 0.0011923406053202302
# INFO:cooler.balance:variance is 0.0008760184787547208
# INFO:cooler.balance:variance is 0.000642677199966165
# INFO:cooler.balance:variance is 0.00047212394612119324
# INFO:cooler.balance:variance is 0.00034646189253913055
# INFO:cooler.balance:variance is 0.00025449912842843736
# INFO:cooler.balance:variance is 0.00018680048905859496
# INFO:cooler.balance:variance is 0.000137210979192785
# INFO:cooler.balance:variance is 0.00010072842251390823
# INFO:cooler.balance:variance is 7.398633750944686e-05
# INFO:cooler.balance:variance is 5.432133036189292e-05
# INFO:cooler.balance:variance is 3.9899225583588334e-05
# INFO:cooler.balance:variance is 2.9297263022020797e-05
# INFO:cooler.balance:variance is 2.151888173036538e-05
# INFO:cooler.balance:variance is 1.5802174219053567e-05
# INFO:cooler.balance:variance is 1.160675218169572e-05
# INFO:cooler.balance:variance is 8.523842143419532e-06
# INFO:root:creating a Pool of 10 workers
# INFO:root:creating a Pool of 10 workers
# Done.
# Processing GSE178982_AsyncAID_pooled…
# prenorm: 2088765526.0
# sampling fraction: 0.14362550332516355
# sampling to ../data/cool_norm_pooled/GSE178982_AsyncAID_pooled_1000bp_downsampled-300M_KR.cool
# normalizing ../data/cool_norm_pooled/GSE178982_AsyncAID_pooled_1000bp_downsampled-300M_KR.cool
# INFO:cooler.cli.balance:Balancing "../data/cool_norm_pooled/GSE178982_AsyncAID_pooled_1000bp_downsampled-300M_KR.cool"
# INFO:cooler.balance:variance is 207648.8928140819
# INFO:cooler.balance:variance is 11337.341290633969
# INFO:cooler.balance:variance is 6512.623180673498
# INFO:cooler.balance:variance is 7458.935719944595
# INFO:cooler.balance:variance is 3677.2096575985875
# INFO:cooler.balance:variance is 4048.94145225271
# INFO:cooler.balance:variance is 1908.6164267195784
# INFO:cooler.balance:variance is 2059.50755482569
# INFO:cooler.balance:variance is 989.2054282202909
# INFO:cooler.balance:variance is 1036.7663274515735
# INFO:cooler.balance:variance is 523.8189490107254
# INFO:cooler.balance:variance is 527.3743424281306
# INFO:cooler.balance:variance is 283.6187567065722
# INFO:cooler.balance:variance is 272.89118012501825
# INFO:cooler.balance:variance is 156.19230917983376
# INFO:cooler.balance:variance is 143.73785815471854
# INFO:cooler.balance:variance is 87.01030572728119
# INFO:cooler.balance:variance is 76.92398479652456
# INFO:cooler.balance:variance is 48.826263775514015
# INFO:cooler.balance:variance is 41.71702875732141
# INFO:cooler.balance:variance is 27.522185268432303
# INFO:cooler.balance:variance is 22.865213069211975
# INFO:cooler.balance:variance is 15.555363955092863
# INFO:cooler.balance:variance is 12.636780178708927
# INFO:cooler.balance:variance is 8.80578419770275
# INFO:cooler.balance:variance is 7.028572803769595
# INFO:cooler.balance:variance is 4.98956221963235
# INFO:cooler.balance:variance is 3.9283816521086297
# INFO:cooler.balance:variance is 2.828786206668101
# INFO:cooler.balance:variance is 2.203815323776314
# INFO:cooler.balance:variance is 1.6043280429187212
# INFO:cooler.balance:variance is 1.2398732457965231
# INFO:cooler.balance:variance is 0.9101273706434033
# INFO:cooler.balance:variance is 0.6991150176555455
# INFO:cooler.balance:variance is 0.5164426507878633
# INFO:cooler.balance:variance is 0.394915339465191
# INFO:cooler.balance:variance is 0.29314169686497576
# INFO:cooler.balance:variance is 0.22342666810942144
# INFO:cooler.balance:variance is 0.16646632466144104
# INFO:cooler.balance:variance is 0.12659312458356578
# INFO:cooler.balance:variance is 0.09459572799205564
# INFO:cooler.balance:variance is 0.07184334355621047
# INFO:cooler.balance:variance is 0.05381274501360032
# INFO:cooler.balance:variance is 0.040854347532171896
# INFO:cooler.balance:variance is 0.030665438300054287
# INFO:cooler.balance:variance is 0.023297407388730942
# INFO:cooler.balance:variance is 0.01752351849840249
# INFO:cooler.balance:variance is 0.013341052129918804
# INFO:cooler.balance:variance is 0.010058618843213199
# INFO:cooler.balance:variance is 0.007688939162618019
# INFO:cooler.balance:variance is 0.005815278939318207
# INFO:cooler.balance:variance is 0.004476008602031852
# INFO:cooler.balance:variance is 0.0034004366289326314
# INFO:cooler.balance:variance is 0.0026462353039833336
# INFO:cooler.balance:variance is 0.0020236995756147008
# INFO:cooler.balance:variance is 0.0016013221152760709
# INFO:cooler.balance:variance is 0.0012365712520802077
# INFO:cooler.balance:variance is 0.0010021263343272138
# INFO:cooler.balance:variance is 0.0007845246202211624
# INFO:cooler.balance:variance is 0.0006563155412650295
# INFO:cooler.balance:variance is 0.0005230859166756875
# INFO:cooler.balance:variance is 0.000454763426063133
# INFO:cooler.balance:variance is 0.00037022800178664386
# INFO:cooler.balance:variance is 0.00033552009631090994
# INFO:cooler.balance:variance is 0.00027936105918895164
# INFO:cooler.balance:variance is 0.00026339343950075096
# INFO:cooler.balance:variance is 0.00022400809395273946
# INFO:cooler.balance:variance is 0.00021837336290266544
# INFO:cooler.balance:variance is 0.00018910949807887794
# INFO:cooler.balance:variance is 0.00018906723101832167
# INFO:cooler.balance:variance is 0.00016608864695656325
# INFO:cooler.balance:variance is 0.00016897609288717776
# INFO:cooler.balance:variance is 0.0001500514593325756
# INFO:cooler.balance:variance is 0.00015438177743357342
# INFO:cooler.balance:variance is 0.00013819682256523477
# INFO:cooler.balance:variance is 0.00014314765288208023
# INFO:cooler.balance:variance is 0.00012891414652546604
# INFO:cooler.balance:variance is 0.0001340377197348161
# INFO:cooler.balance:variance is 0.00012127087806756807
# INFO:cooler.balance:variance is 0.00012632982530896248
# INFO:cooler.balance:variance is 0.00011472135274445211
# INFO:cooler.balance:variance is 0.00011959581300714874
# INFO:cooler.balance:variance is 0.00010894129460452436
# INFO:cooler.balance:variance is 0.00011357644523518777
# INFO:cooler.balance:variance is 0.00010373365871173356
# INFO:cooler.balance:variance is 0.00010811015120682903
# INFO:cooler.balance:variance is 9.897499405290411e-05
# INFO:cooler.balance:variance is 0.00010309235828591158
# INFO:cooler.balance:variance is 9.458483062986655e-05
# INFO:cooler.balance:variance is 9.845221277430042e-05
# INFO:cooler.balance:variance is 9.05081573733664e-05
# INFO:cooler.balance:variance is 9.413919774078778e-05
# INFO:cooler.balance:variance is 8.670534993867781e-05
# INFO:cooler.balance:variance is 9.011539162980583e-05
# INFO:cooler.balance:variance is 8.314634394515879e-05
# INFO:cooler.balance:variance is 8.63509484891231e-05
# INFO:cooler.balance:variance is 7.980723244673099e-05
# INFO:cooler.balance:variance is 8.282142378885261e-05
# INFO:cooler.balance:variance is 7.666825184136398e-05
# INFO:cooler.balance:variance is 7.950616229495615e-05
# INFO:cooler.balance:variance is 7.371256652463614e-05
# INFO:cooler.balance:variance is 7.638730113396623e-05
# INFO:cooler.balance:variance is 7.092551605993685e-05
# INFO:cooler.balance:variance is 7.34491326105548e-05
# INFO:cooler.balance:variance is 6.829413273456517e-05
# INFO:cooler.balance:variance is 7.067768027276739e-05
# INFO:cooler.balance:variance is 6.580681935522309e-05
# INFO:cooler.balance:variance is 6.806040378663234e-05
# INFO:cooler.balance:variance is 6.345312383579694e-05
# INFO:cooler.balance:variance is 6.558598360920223e-05
# INFO:cooler.balance:variance is 6.122357377591012e-05
# INFO:cooler.balance:variance is 6.32441567232528e-05
# INFO:cooler.balance:variance is 5.910954946957447e-05
# INFO:cooler.balance:variance is 6.102558634313708e-05
# INFO:cooler.balance:variance is 5.7103182532475224e-05
# INFO:cooler.balance:variance is 5.8921755227625026e-05
# INFO:cooler.balance:variance is 5.5197272385144523e-05
# INFO:cooler.balance:variance is 5.692487615082989e-05
# INFO:cooler.balance:variance is 5.3385215764855884e-05
# INFO:cooler.balance:variance is 5.502781538638817e-05
# INFO:cooler.balance:variance is 5.166094616439248e-05
# INFO:cooler.balance:variance is 5.32240264368398e-05
# INFO:cooler.balance:variance is 5.0018881125080194e-05
# INFO:cooler.balance:variance is 5.150749207982251e-05
# INFO:cooler.balance:variance is 4.8453875938306424e-05
# INFO:cooler.balance:variance is 4.987267332870991e-05
# INFO:cooler.balance:variance is 4.6961182701555165e-05
# INFO:cooler.balance:variance is 4.8314464245712685e-05
# INFO:cooler.balance:variance is 4.553641392840274e-05
# INFO:cooler.balance:variance is 4.682815177440646e-05
# INFO:cooler.balance:variance is 4.4175510082056315e-05
# INFO:cooler.balance:variance is 4.5409379919004756e-05
# INFO:cooler.balance:variance is 4.2874710521288584e-05
# INFO:cooler.balance:variance is 4.405411771478467e-05
# INFO:cooler.balance:variance is 4.1630527434751886e-05
# INFO:cooler.balance:variance is 4.2758630522852984e-05
# INFO:cooler.balance:variance is 4.043972240586898e-05
# INFO:cooler.balance:variance is 4.151945425200949e-05
# INFO:cooler.balance:variance is 3.9299285302545895e-05
# INFO:cooler.balance:variance is 4.033337216653661e-05
# INFO:cooler.balance:variance is 3.8206415227996666e-05
# INFO:cooler.balance:variance is 3.919739398477021e-05
# INFO:cooler.balance:variance is 3.715850330365838e-05
# INFO:cooler.balance:variance is 3.810873701183925e-05
# INFO:cooler.balance:variance is 3.615311708431808e-05
# INFO:cooler.balance:variance is 3.706480908247854e-05
# INFO:cooler.balance:variance is 3.5187986430237244e-05
# INFO:cooler.balance:variance is 3.6063193117627e-05
# INFO:cooler.balance:variance is 3.4260990682266264e-05
# INFO:cooler.balance:variance is 3.5101633122323667e-05
# INFO:cooler.balance:variance is 3.3370147004151264e-05
# INFO:cooler.balance:variance is 3.417802147303531e-05
# INFO:cooler.balance:variance is 3.251359977206407e-05
# INFO:cooler.balance:variance is 3.3290387360370594e-05
# INFO:cooler.balance:variance is 3.1689610905135324e-05
# INFO:cooler.balance:variance is 3.243688626866535e-05
# INFO:cooler.balance:variance is 3.0896551042758654e-05
# INFO:cooler.balance:variance is 3.161579038743422e-05
# INFO:cooler.balance:variance is 3.0132891484957306e-05
# INFO:cooler.balance:variance is 3.082547986152345e-05
# INFO:cooler.balance:variance is 2.93971968212825e-05
# INFO:cooler.balance:variance is 3.0064434797145003e-05
# INFO:cooler.balance:variance is 2.8688118181837984e-05
# INFO:cooler.balance:variance is 2.9331227950086406e-05
# INFO:cooler.balance:variance is 2.8004387051128223e-05
# INFO:cooler.balance:variance is 2.8624518030335797e-05
# INFO:cooler.balance:variance is 2.7344809591712244e-05
# INFO:cooler.balance:variance is 2.794304356448044e-05
# INFO:cooler.balance:variance is 2.6708261430226784e-05
# INFO:cooler.balance:variance is 2.728561726335356e-05
# INFO:cooler.balance:variance is 2.6093682863207415e-05
# INFO:cooler.balance:variance is 2.6651120847989377e-05
# INFO:cooler.balance:variance is 2.5500074444537045e-05
# INFO:cooler.balance:variance is 2.6038500291725077e-05
# INFO:cooler.balance:variance is 2.4926492920186393e-05
# INFO:cooler.balance:variance is 2.544676144065824e-05
# INFO:cooler.balance:variance is 2.437204747935963e-05
# INFO:cooler.balance:variance is 2.4874965978440408e-05
# INFO:cooler.balance:variance is 2.3835896294212326e-05
# INFO:cooler.balance:variance is 2.4322227704829993e-05
# INFO:cooler.balance:variance is 2.331724332302271e-05
# INFO:cooler.balance:variance is 2.378770910041035e-05
# INFO:cooler.balance:variance is 2.281533535415828e-05
# INFO:cooler.balance:variance is 2.3270618152616516e-05
# INFO:cooler.balance:variance is 2.232945927030379e-05
# INFO:cooler.balance:variance is 2.27702054205854e-05
# INFO:cooler.balance:variance is 2.185893951442419e-05
# INFO:cooler.balance:variance is 2.2285761318522165e-05
# INFO:cooler.balance:variance is 2.1403135740606643e-05
# INFO:cooler.balance:variance is 2.1816613599174274e-05
# INFO:cooler.balance:variance is 2.0961440634551786e-05
# INFO:cooler.balance:variance is 2.136212502075714e-05
# INFO:cooler.balance:variance is 2.0533277889841446e-05
# INFO:cooler.balance:variance is 2.092169118219578e-05
# INFO:cooler.balance:variance is 2.011810032739116e-05
# INFO:cooler.balance:variance is 2.049473851295093e-05
# INFO:cooler.balance:variance is 1.9715388146624545e-05
# INFO:cooler.balance:variance is 2.0080722404941823e-05
# INFO:cooler.balance:variance is 1.9324647297936724e-05
# INFO:cooler.balance:variance is 1.9679125475194134e-05
# ERROR:cooler.cli.balance:Iteration limit reached without convergence
# ERROR:cooler.cli.balance:Storing final result. Check log to assess convergence.
# INFO:root:creating a Pool of 10 workers
# Done.
